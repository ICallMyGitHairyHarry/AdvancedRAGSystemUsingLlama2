# %% [markdown]
# ## RAG System Using Llama2

# %% [markdown]
# ### Установка библиотек

# %% [markdown]
# Pypdf для работы с pdf-документами.
# Идея заключается в том что, если у нас много PDF-документов, мы должны иметь возможность загружать эти PDF-документы, индексировать эти PDFдокументы и выполнять запросы вместе с моделью Lama2.

# %%
# !pip install pypdf
# Out:
# Collecting pypdf
#   Downloading pypdf-4.1.0-py3-none-any.whl (286 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.1/286.1 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: pypdf
# Successfully installed pypdf-4.1.0

# %% [markdown]
# Transformers предоставляет API и инструменты для простой загрузки и настройки современных предварительно обученных моделей.
#
# Einops - Эта библиотека предоставляет инструменты для работы с тензорами, в частности, для изменения формы, перестановки и уменьшения размеров в многомерных массивах (тензорах).
#
# Accelerate - это библиотека, которая позволяет запускать один и тот же основной код на распределенной конфигурации. Нужна чтобы ускорить процессы.
#
# LangChain - это фреймворк для разработки приложений на базе LLM.
#
# Bitsandbytes предоставляет функции, позволяющие значительно сократить потребление памяти для ответов и обучения. большинство моделей большинство моделей llm содержат 16 бит, но поскольку мы в Google collab, то будем квантовать их до 4х бит.

# %%
# !pip install -q transformers einops accelerate langchain bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.3/297.3 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.8/812.8 kB 13.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 19.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.8/276.8 kB 21.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 19.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 62.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 67.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 85.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 68.0 MB/s eta 0:00:00

# %% [markdown]
# Sentence_transformers для работы с эмбеддингами.

# %%
# !pip install install sentence_transformers
# Out:
# Collecting install
#   Downloading install-1.3.5-py3-none-any.whl (3.2 kB)
# Collecting sentence_transformers
#   Downloading sentence_transformers-2.6.1-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.3/163.3 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.38.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (3.13.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence_transformers) (12.4.127)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (0.4.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)
# Installing collected packages: install, sentence_transformers
# Successfully installed install-1.3.5 sentence_transformers-2.6.1

# %% [markdown]
# LlamaIndex (GPT Index) - фреймворк, который предоставляет интерфейс для подключения LLM к внешним данным.

# %%
# !pip install llama_index
# Out:
# Collecting llama_index
#   Downloading llama_index-0.10.27-py3-none-any.whl (6.9 kB)
# Collecting llama-index-agent-openai<0.3.0,>=0.1.4 (from llama_index)
#   Downloading llama_index_agent_openai-0.2.2-py3-none-any.whl (12 kB)
# Collecting llama-index-cli<0.2.0,>=0.1.2 (from llama_index)
#   Downloading llama_index_cli-0.1.11-py3-none-any.whl (26 kB)
# Collecting llama-index-core<0.11.0,>=0.10.27 (from llama_index)
#   Downloading llama_index_core-0.10.27-py3-none-any.whl (15.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 49.1 MB/s eta 0:00:00
# Collecting llama-index-embeddings-openai<0.2.0,>=0.1.5 (from llama_index)
#   Downloading llama_index_embeddings_openai-0.1.7-py3-none-any.whl (6.0 kB)
# Collecting llama-index-indices-managed-llama-cloud<0.2.0,>=0.1.2 (from llama_index)
#   Downloading llama_index_indices_managed_llama_cloud-0.1.5-py3-none-any.whl (6.7 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48 (from llama_index)
#   Downloading llama_index_legacy-0.9.48-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 60.4 MB/s eta 0:00:00
# Collecting llama-index-llms-openai<0.2.0,>=0.1.13 (from llama_index)
#   Downloading llama_index_llms_openai-0.1.14-py3-none-any.whl (10 kB)
# Collecting llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 (from llama_index)
#   Downloading llama_index_multi_modal_llms_openai-0.1.4-py3-none-any.whl (5.8 kB)
# Collecting llama-index-program-openai<0.2.0,>=0.1.3 (from llama_index)
#   Downloading llama_index_program_openai-0.1.5-py3-none-any.whl (4.1 kB)
# Collecting llama-index-question-gen-openai<0.2.0,>=0.1.2 (from llama_index)
#   Downloading llama_index_question_gen_openai-0.1.3-py3-none-any.whl (2.9 kB)
# Collecting llama-index-readers-file<0.2.0,>=0.1.4 (from llama_index)
#   Downloading llama_index_readers_file-0.1.13-py3-none-any.whl (36 kB)
# Collecting llama-index-readers-llama-parse<0.2.0,>=0.1.2 (from llama_index)
#   Downloading llama_index_readers_llama_parse-0.1.4-py3-none-any.whl (2.5 kB)
# Collecting openai>=1.14.0 (from llama-index-agent-openai<0.3.0,>=0.1.4->llama_index)
#   Downloading openai-1.16.2-py3-none-any.whl (267 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 23.6 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (6.0.1)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (2.0.29)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (3.9.3)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (0.6.4)
# Collecting deprecated>=1.2.9.3 (from llama-index-core<0.11.0,>=0.10.27->llama_index)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core<0.11.0,>=0.10.27->llama_index)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (2023.6.0)
# Collecting httpx (from llama-index-core<0.11.0,>=0.10.27->llama_index)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 12.1 MB/s eta 0:00:00
# Collecting llamaindex-py-client<0.2.0,>=0.1.16 (from llama-index-core<0.11.0,>=0.10.27->llama_index)
#   Downloading llamaindex_py_client-0.1.16-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.0/136.0 kB 19.0 MB/s eta 0:00:00
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (2.0.3)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (9.4.0)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (8.2.3)
# Collecting tiktoken>=0.3.3 (from llama-index-core<0.11.0,>=0.10.27->llama_index)
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 89.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (4.10.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.27->llama_index) (1.14.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index) (4.12.3)
# Collecting pymupdf<2.0.0,>=1.23.21 (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index)
#   Downloading PyMuPDF-1.24.1-cp310-none-manylinux2014_x86_64.whl (3.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 68.5 MB/s eta 0:00:00
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index) (4.1.0)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index)
#   Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Collecting llama-parse<0.5.0,>=0.4.0 (from llama-index-readers-llama-parse<0.2.0,>=0.1.2->llama_index)
#   Downloading llama_parse-0.4.0-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.27->llama_index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.27->llama_index) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.27->llama_index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.27->llama_index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.27->llama_index) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.27->llama_index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama_index) (2.5)
# Requirement already satisfied: pydantic>=1.10 in /usr/local/lib/python3.10/dist-packages (from llamaindex-py-client<0.2.0,>=0.1.16->llama-index-core<0.11.0,>=0.10.27->llama_index) (2.6.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.27->llama_index) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.27->llama_index) (2024.2.2)
# Collecting httpcore==1.* (from httpx->llama-index-core<0.11.0,>=0.10.27->llama_index)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.27->llama_index) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.27->llama_index) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.27->llama_index)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.27->llama_index) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.27->llama_index) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.27->llama_index) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.3.0,>=0.1.4->llama_index) (1.7.0)
# Collecting PyMuPDFb==1.24.1 (from pymupdf<2.0.0,>=1.23.21->llama-index-readers-file<0.2.0,>=0.1.4->llama_index)
#   Downloading PyMuPDFb-1.24.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (30.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 13.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.27->llama_index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.27->llama_index) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.27->llama_index) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.27->llama_index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.27->llama_index) (3.21.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.27->llama_index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.27->llama_index) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.27->llama_index) (2024.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.27->llama_index) (1.2.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.27->llama_index) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.16->llama-index-core<0.11.0,>=0.10.27->llama_index) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.16->llama-index-core<0.11.0,>=0.10.27->llama_index) (2.16.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.27->llama_index) (1.16.0)
# Installing collected packages: striprtf, dirtyjson, PyMuPDFb, h11, deprecated, tiktoken, pymupdf, httpcore, httpx, openai, llamaindex-py-client, llama-index-legacy, llama-index-core, llama-parse, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-program-openai, llama-index-question-gen-openai, llama_index
# Successfully installed PyMuPDFb-1.24.1 deprecated-1.2.14 dirtyjson-1.0.8 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 llama-index-agent-openai-0.2.2 llama-index-cli-0.1.11 llama-index-core-0.10.27 llama-index-embeddings-openai-0.1.7 llama-index-indices-managed-llama-cloud-0.1.5 llama-index-legacy-0.9.48 llama-index-llms-openai-0.1.14 llama-index-multi-modal-llms-openai-0.1.4 llama-index-program-openai-0.1.5 llama-index-question-gen-openai-0.1.3 llama-index-readers-file-0.1.13 llama-index-readers-llama-parse-0.1.4 llama-parse-0.4.0 llama_index-0.10.27 llamaindex-py-client-0.1.16 openai-1.16.2 pymupdf-1.24.1 striprtf-0.0.26 tiktoken-0.6.0

# %% [markdown]
# Сопутсвующая к llamaindex библиотека для работы с LLM huggingface.

# %%
# !pip install llama-index-llms-huggingface
# Out:
# Collecting llama-index-llms-huggingface
#   Downloading llama_index_llms_huggingface-0.1.4-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: huggingface-hub<0.21.0,>=0.20.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-llms-huggingface) (0.20.3)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-llms-huggingface) (0.10.27)
# Requirement already satisfied: torch<3.0.0,>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from llama-index-llms-huggingface) (2.2.1+cu121)
# Requirement already satisfied: transformers[torch]<5.0.0,>=4.37.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-llms-huggingface) (4.38.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (3.13.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (4.66.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (23.2)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2.0.29)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (3.9.3)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (0.6.4)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.0.8)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (0.27.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.16 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (0.1.16)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.25.2)
# Requirement already satisfied: openai>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.16.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2.0.3)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (9.4.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (0.6.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.14.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (12.4.127)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (0.4.2)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (0.29.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (5.9.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (4.0.3)
# Requirement already satisfied: pydantic>=1.10 in /usr/local/lib/python3.10/dist-packages (from llamaindex-py-client<0.2.0,>=0.1.16->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2.6.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (0.14.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.3.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<0.21.0,>=0.20.3->llama-index-llms-huggingface) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (3.21.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.16->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.16->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (2.16.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-huggingface) (1.16.0)
# Installing collected packages: llama-index-llms-huggingface
# Successfully installed llama-index-llms-huggingface-0.1.4

# %% [markdown]
# Импорт компонентов из библиотек:
#
# * SimpleDirectoryReader для загрузки локальных файлов.
# * VectorStoreIndex для индексирования документов и создания векторов.
# * ServiceContext для соединения LLM и Эмбединг-модели.
# * HuggingfaceLLM для взаимодействия с моделями Hugging Face.
# * SimpleInputPrompt для создания prompt format (формата промпта).

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, ServiceContext
from llama_index.llms.huggingface import HuggingFaceLLM
from llama_index.core.prompts.prompts import SimpleInputPrompt

# %% [markdown]
# ### Настройка RAG и LLM

# %% [markdown]
# Подключение гугл диска для хранения файлов, чтобы они не удалялись при отключении от среды выполнения.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Загрузка локальных файлов с помощью SimpleDirectoryReader.

# %%
documents=SimpleDirectoryReader("/content/drive/MyDrive/data").load_data()
documents
# Out:
# [Document(id_='407fc6df-d66d-4ec7-9249-6a3a2e8dc903', embedding=None, metadata={'page_label': '1', 'file_name': '00_ViPNet SIES DevKit. Развертывание.pdf', 'file_path': '/content/drive/MyDrive/data/00_ViPNet SIES DevKit. Развертывание.pdf', 'file_type': 'application/pdf', 'file_size': 1407347, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Комплект разработчика ViPNet SIES . Развёртывание   |  1  \nКомплект разработчика \nViPNet SIES  \nРазвёртывание  \n \n \n ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='388b9cfd-d4bc-433b-a263-1910fa2edcf6', embedding=None, metadata={'page_label': '2', 'file_name': '00_ViPNet SIES DevKit. Развертывание.pdf', 'file_path': '/content/drive/MyDrive/data/00_ViPNet SIES DevKit. Развертывание.pdf', 'file_type': 'application/pdf', 'file_size': 1407347, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='  \n \n© АО «ИнфоТеКС», 2022  \nФРКЕ.00192 -03 33 03  \nВерсия продукта 2.4  \nЭтот документ входит в комплект поставки ViPNet SIES, и на него распространяются все условия лицензионного соглашения.  \nНи одна из частей этого документа не может быть  воспроизведена, опубликована, сохранена в электронной базе данных \nили передана в любой форме или любыми средствами, такими как электронные, механические, записывающие или иначе, \nдля любой цели без предварительного письменного разрешения АО «ИнфоТеКС».  \nViPNet® является зарегистрированным товарным знаком АО «ИнфоТеКС».  \nВ продукте использовано изобретение, защищенное патентом РФ № 2706176.  \nВсе названия компаний и продуктов, которые являются товарными знаками или зарегистрированными товарными знаками, \nпринадлежат соответствующим владельцам.  \nАО «ИнфоТеКС»  \n127083, Москва, улица Мишина, д. 56, стр. 2, этаж 2, помещение IX, комната 29  \nТелефон: +7 (495) 737 -6192, 8 (800) 250 -0260 — бесплатный звонок из России (кроме Москвы)  \nСайт: infotecs.ru  \nСлужба поддержки: hotline@infotecs.ru  \nCopy rig ht (c) Inf oT e CS . A ll Rig hts R e se rv e d  \n ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='41e7f7e1-a461-4e92-8aa8-267772ac5756', embedding=None, metadata={'page_label': '3', 'file_name': '00_ViPNet SIES DevKit. Развертывание.pdf', 'file_path': '/content/drive/MyDrive/data/00_ViPNet SIES DevKit. Развертывание.pdf', 'file_type': 'application/pdf', 'file_size': 1407347, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='  \nСодержание  \nО документе  ................................ ................................ ................................ ................................ .........................  4 \nО комплекте разработчика ................................ ................................ ................................ ..............................  4 \nЦелевые стенды  ................................ ................................ ................................ ................................ .................  7 \nСтенд для исполнений 1 и 3 ................................ ................................ ................................ ................................ . 7 \nСтенд для исполнений 2 и 4 ................................ ................................ ................................ ................................ . 9 \nИнфраструктура управления комплексом ViPNet SIES  ................................ ................................ ...........  11 \nРазвёртывание комплекта разработчика ViPNet SIES  ................................ ................................ ............. 13 \nОрганизация рабочего места администратора безопасности в исполнениях 1 и 2  .............  16 \nПодключение рабочего места администратора безопасности в исполнениях 3 и 4  ...........  17 \nУстановка ViPNet SIE S MC в исполнениях 1 и 2  ................................ ................................ .......................  18 \nУстановка ViPNet SIES Workstation в исполнении 1  ................................ ................................ ...............  24 \nУстановка ViPNet SIES Workstation в исполнении 3  ................................ ................................ ...............  25 \nУстановка ViPNet SIES Core в исполнениях 1 и 3 ................................ ................................ .....................  26 \nУстановка ViPNet SIES Unit в исполнениях 1 и 3  ................................ ................................ ......................  27 \nУстановка ViPNet SIES Unit в исполнениях 2 и 4  ................................ ................................ ......................  27 \nУстановка СКЗИ другого производителя в исполнениях 2 и 4  ................................ ........................  28 \nПодготовка устройства аутентификации инженера, оператора или пользователя в \nлюбом исполнении  ................................ ................................ ................................ ................................ ................  28 \nПодгот овка к реализации сценария защиты данных  ................................ ................................ .............  29 \nРеализация сценария защиты данных  ................................ ................................ ................................ ....... 30 \nВозможные неполадки  ................................ ................................ ................................ ................................ ... 33 \nНе запускается виртуальная машина ViPNet SIES MC VA в гипервизоре VMware \nWorkstation  ................................ ................................ ................................ ................................ .......................  33 \n  ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}',  ...
#  Document(id_='47c4fd40-022c-4df5-ac87-f4882a6dbd12', embedding=None, metadata={'page_label': '4', 'file_name': '00_ViPNet SIES DevKit. Развертывание.pdf', 'file_path': '/content/drive/MyDrive/data/00_ViPNet SIES DevKit. Развертывание.pdf', 'file_type': 'application/pdf', 'file_size': 1407347, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Комплект разработчика ViPNet SIES . Развёртывание   |  4  \n  \nО документе  \nВ документе приведена методика развертывания и применения комплекта разработчика ViPNet \nSIES в экспериментальных сценариях защиты данных, которые приведены в документе «ViPNet SIES. \nСценарии работы». Реализация сценариев послужит основой для разработки интеграционного \nрешения по внедрению комплекса ViPNet SIES в индустриальной системе.  \nДокумент предназначен для технических специалистов, разрабатывающих решение по внедрению \nкомплекса V iPNet SIES в индустриальной системе.  \nПредполагается, что читатель обладает базовым представлением об устройстве компьютерных и \nиндустриальных систем, опытом работы с сертификатами ключа проверки электронной подписи и \nразработки программного обеспечения, на выками начинающего администратора Windows.  \nО комплекте разработчика  \nС помощью комплекта разработчика ViPNet SIES можно организовать стенд с использованием \nсредств криптографической защиты информации (далее – СКЗИ) из комплекса ViPNet SIES. Стенд \nпозволит р еализовать сценарии защиты данных для индустриальных устройств, приведенные в \nдокументе «ViPNet SIES. Сценарии работы». Реализация сценариев послужит основой для \nразработки интеграционного решения по внедрению комплекса ViPNet SIES в индустриальной \nсистеме . \nВыберите исполнение комплекта разработчика в зависимости:  \n\uf0b7 от типа индустриального устройства, которое будете интегрировать с SIES -узлом;  \n\uf0b7 возможностей по развёртыванию и поддержания инфраструктуры управления комплексом \nViPNet SIES.  \n ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='84f5e018-f856-4d49-b627-bed5b442eede', embedding=None, metadata={'page_label': '5', 'file_name': '00_ViPNet SIES DevKit. Развертывание.pdf', 'file_path': '/content/drive/MyDrive/data/00_ViPNet SIES DevKit. Развертывание.pdf', 'file_type': 'application/pdf', 'file_size': 1407347, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Комплект разработ чика ViPNet SIES . Развёртывание   |  5  \nТаблица 1. Исполнения комплекта разработчика ViPNet SIES  \n Исполнение 1  Исполнение 2  Исполнение 3  Исполнение  4 \nНазначение  \uf0b7 Разработчикам устройств \nавтоматизации среднего и \nнижнего уровней \nиндустриальной системы  \n\uf0b7 Разработчикам защищённой \nиндустриальной системы  \uf0b7 Разработчикам ПО устройств \nверхнего уровня, \nSCADA -серверов  \n\uf0b7 Разработчикам, использующим \nСКЗИ других производителей \n(SIES -узлов типа Другой) в \nкомплексе ViPNet SIES  Разработчикам устройств \nавтоматизации среднего и \nнижнего уровней \nиндустриальной системы  \uf0b7 Разработчикам ПО устройств \nверхнего уровня, \nSCADA -серверов  \n\uf0b7 Разработчикам, \nиспользующим СКЗИ других \nпроизводителей (SIES -узлов \nтипа Другой) в комплексе \nViPNet SIES  \nКомпоненты в \nсоставе исполнения  Самостоятельное развёртывание инфраструктуры управления \nкомплексом ViPNet SIES  Использование инфраструктуры управления комплексом ViPNet \nSIES, развернутой в ИнфоТеКСе  \nViPNet SIES MC VA  1 шт.  1 шт.  Возможность подключения к \nоблачному ViPNet SIES MC  Возможность подключения к \nоблачному ViPNet SIES MC  \nViPNet SIES Unit  1 шт. для Windows или Linux на \nвыбор  1 шт. для Windows или Linux на \nвыбор  1 шт. для Windows или  Linux на \nвыбор  1 шт. для Windows или Linux на \nвыбор  \nViPNet SIES Core  2 шт.  ☓ 2 шт.  ☓ \nViPNet SIES Core SDK  ✓ ☓ ✓ ☓ \nViPNet SIES \nWorkstation  1 шт.  ☓ 1 шт.  ☓ \nЛицензия ViPNet SIES \nMC на ViPNet SIES \nUnit 1 шт. на 50 прикладных связей  2 шт. на 50 прикладных связей  1 шт. на 50 прикладных связей  2 шт. на 50 прикладных связей  \nЛицензия ViPNet SIES \nMC на ViPNet SIES \nWorstation  1 шт.  ☓ 1 шт.  ☓ ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='b40a72e0-c071-4aaa-86b9-de954bc7dcb0', embedding=None, metadata={'page_label': '6', 'file_name': '00_ViPNet SIES DevKit. Развертывание.pdf', 'file_path': '/content/drive/MyDrive/data/00_ViPNet SIES DevKit. Развертывание.pdf', 'file_type': 'application/pdf', 'file_size': 1407347, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Комплект разработ чика ViPNet SIES . Развёртывание   |  6  \n Исполнение 1  Исполнение 2  Исполнение 3  Исполнение  4 \nЛицензия ViPNet SIES \nMC на SIES -узел типа \nПользователь  2 шт.  2 шт.  2 шт.  2 шт.  \nЛицензия ViPNet SIES \nMC на SIES -узел типа  \nДругой  ☓ 2 шт.  ☓ 2 шт.  \nЛицензия \nадминистратора \nViPNet SIES MC  1 шт.  1 шт.  1 шт.  1 шт.  \nViPNet PKI Client с TLS \nUnit для \nподключения \nадминистратора \nViPNet SIES MC  1 шт. для Windows  1 шт. для Windows  1 шт. для Windows  1 шт. для Windows или Linux на \nвыбор  \nЛицензия ViPNet PKI \nClient с TLS Unit  1 шт.  1 шт.  1 шт.  1 шт.  \n \n ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='684b924e-1092-4cdc-93c6-832b5c6b5d4d', embedding=None, metadata={'page_label': '7', 'file_name': '00_ViPNet SIES DevKit. Развертывание.pdf', 'file_path': '/content/drive/MyDrive/data/00_ViPNet SIES DevKit. Развертывание.pdf', 'file_type': 'application/pdf', 'file_size': 1407347, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Комплект разработчика ViPNet SIES . Развёртывание   |  7  \nЦелевые стенды  \nСтруктура целевого стенда зависит от используемого исполнения комплекта разработчика ViPNet \nSIES. \nСтенд для исполнений 1 и 3  \nИсполнения 1 и 3 предназначены для разработчиков:  \n\uf0b7 устройств автоматизации среднего и нижнего уровней;  \n\uf0b7 защищённой индустриальной системы.  \nИсполнения 1 и 3 и позволяет организовать:  \n\uf0b7 работы по встраиванию (интеграции) СКЗИ ViPNet SIES Core:  \no в программируемые логические контроллеры (ПЛК);  \no шлюзы промышленного интернета вещей (IIoT -шлюзы);  \no коммуникационные шлюзы;  \no устройства передачи данных (УСПД);  \n\uf0b7 работы по встраиванию (инте грации) СКЗИ ViPNet SIES Unit в ПО устройств верхнего уровня;  \n\uf0b7 сценарий аутентификации инженера, оператора или пользователя индустриальной системы \nперед защищаемыми устройствами.  \nИспользуя компоненты исполнения 1 или 3 можно организовать защиту информации в  \nиндустриальной системе, представленной на рисунке ниже. Элементы системы необязательные и \nмогут отсутствовать. При развёртывании и тестировании можно использовать индустриальные \nустройства или эмуляторы, развёрнутые на отдельных компьютерах или виртуальны х машинах.  ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='e89e7fe9-e919-4099-903a-b5040b7691b6', embedding=None, metadata={'page_label': '8', 'file_name': '00_ViPNet SIES DevKit. Развертывание.pdf', 'file_path': '/content/drive/MyDrive/data/00_ViPNet SIES DevKit. Развертывание.pdf', 'file_type': 'application/pdf', 'file_size': 1407347, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Комплект разработчика ViPNet SIES . Развёртывание   |  8  \n \nРисунок  1. Вариант развёртывания стенда  \nДля ознакомления c работой ViPNet SIES Core рекомендуется на эмулятор ПЛК установить утилиту \nsies  из состава ViPNet SIES Core SDK, которая позволяет вызывать функции ViPNet SIES Core без \nразработки программного модуля взаимодействия с ViPNet SIES Core.  \nСистемные требования  \n\uf0b7 ПЛК (эмулятор) — компьютер или виртуальная машина с ОС:  \no Debian 7 armel;  \no Debian 7 armhf;  \no Debian 7 (32/64 -разрядная);  \no Ubuntu 12.04 (32/64 -разрядная);  \no Windows 7 (32/64 -разрядная);  \no Windows 8 (32/64 -разрядная);  \no Windows 8.1 (32/64 -разрядная);  \no Windows 10 (32/64 -разрядная);  \no Windows Embedded Standard 7 (SP1) 32 -разрядная;  \no Windows Embedded 8 S tandard (32/64 -разрядная);  ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='890c65f5-036b-4be9-9c51-c13a7f55ccf7', embedding=None, metadata={'page_label': '9', 'file_name': '00_ViPNet SIES DevKit. Развертывание.pdf', 'file_path': '/content/drive/MyDrive/data/00_ViPNet SIES DevKit. Развертывание.pdf', 'file_type': 'application/pdf', 'file_size': 1407347, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Комплект разработчика ViPNet SIES . Развёртывание   |  9  \no Windows Embedded 8.1 Industry (32/64 -разрядная);  \no Windows 10 IoT Enterprise 32 -разрядная.  \n \n Примечание.  При реализации обработки защищенных конвертов ViPNet SIES MC с \nпомощью функции SiesCryptomoduleExecuteMcCommand на реальном ПЛК следует \nобеспечить наличие свободных 10 Мбайт оперативной памяти.  \nПри подключении ViPNet SIES Core к реальному ПЛК через интерф ейс USB, в ПЛК должна \nбыть реализована поддержка подкласса Abstract Control Model (ACM), определенного в \nстандарте USB Communication Device Class (CDC).  \n\uf0b7 SCADA (эмулятор) — компьютер или виртуальная машина с ОС:  \no Windows 8.1 (32/64 -разрядная);  \no Windows 10 (3 2/64-разрядная);  \no Windows Server 2012 (64 -разрядная);  \no Windows Server 2012 R2 (64 -разрядная);  \no Windows Server 2016 (64 -разрядная);  \no Astra Linux Special Edition (Смоленск) 1.6;  \no Debian 9.8 (32/64 -разрядная);  \no Debian 10 (32/64 -разрядная);  \no Ubuntu 16.04 LTS (32/64 -разрядная);  \no Ubuntu 18.04 LTS (64 -разрядная);  \no Debian 9.8 armhf;  \no Debian 10 armhf.  \n\uf0b7 Токен для аутентификации пользователя с функцией создания электронной подписи по ГОСТ Р \n34.10 –2012 с длиной ключа проверки подписи 512 бит.  \nСтенд для исполнений 2 и 4  \nИсполнения  2 и 4 предназначены для разработчиков:  \n\uf0b7 ПО устройств верхнего уровня;  \no SCADA -серверов;  \no АРМ операторов;  \no АРМ инженеров;  \n\uf0b7 использующим СКЗИ других производителей в комплексе ViPNet SIES.  \nИспользуя компоненты исполнения 2 или 4 можно организовать защиту информации \nSCADA -сервера, АРМ оператора или АРМ инженера на стендах, представленных на рисунках ниже. ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='1be3c58b-6631-4e17-aed4-ad710016fa64', embedding=None, metadata={'page_label': '10', 'file_name': '00_ViPNet SIES DevKit. Развертывание.pdf', 'file_path': '/content/drive/MyDrive/data/00_ViPNet SIES DevKit. Развертывание.pdf', 'file_type': 'application/pdf', 'file_size': 1407347, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Комплект разработчика ViPNet SIES . Развёртывание   |  10  \nЭлементы стендов необязательные и могут отсутствовать. При развёртывании и тестировании \nможно использовать индустриальные устройства или эмуляторы, развёр нутые на отдельных \nкомпьютерах или виртуальных машинах.  \n \nРисунок  2. Вариант 1 развёртывания стенда  \nПри использовании СКЗИ других производителей или собственной разработки, работающих \nсовместно с комплексом ViPNet SIES, с помощью к омпонентов исполнений 2 и 4 можно развернуть \nстенд, представленный на рисунке ниже. Элементы стенда необязательные и могут отсутствовать.  \n \nРисунок  3. Вариант 2 развёртывания стенда  \n ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='289706ae-5193-453f-b526-357bae0620c8', embedding=None, metadata={'page_label': '11', 'file_name': '00_ViPNet SIES DevKit. Развертывание.pdf', 'file_path': '/content/drive/MyDrive/data/00_ViPNet SIES DevKit. Развертывание.pdf', 'file_type': 'application/pdf', 'file_size': 1407347, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Комплект разработчика ViPNet SIES . Развёртывание   |  11  \n Примечание.  СКЗИ других производителей не вход ят в комплект поставки исполнений 2 \nи 4. Системные требования для ПЛК (эмулятора) уточняйте у разработчика СКЗИ.  \nСистемные требования  \n\uf0b7 SCADA (эмулятор) — компьютер или виртуальная машина с ОС:  \no Windows 8.1 (32/64 -разрядная);  \no Windows 10 (32/64 -разрядная);  \no Windows Server 2012 (64 -разрядная);  \no Windows Server 2012 R2 (64 -разрядная);  \no Windows Server 2016 (64 -разрядная);  \no Astra Linux Special Edition (Смоленск) 1.6;  \no Debian 9.8 (32/64 -разрядная);  \no Debian 10 (32/64 -разрядная);  \no Ubuntu 16.04 LTS (32/64 -разрядная);  \no Ubuntu  18.04 LTS (64 -разрядная);  \no Debian 9.8 armhf;  \no Debian 10 armhf.  \n\uf0b7 Токен для аутентификации пользователя с функцией создания электронной подписи по ГОСТ Р \n34.10 –2012 с длиной ключа проверки подписи 512 бит.  \nИнфраструктура управления \nкомплексом ViPNet SIES  \nДля и спользования целевого стенда следует организовать инфраструктуру управления комплексом \nViPNet SIES в составе:  \n\uf0b7 центр управления ViPNet SIES MC:  \no для создания ключевой информации и сертификатов;  \no управления прикладными связями между защищаемыми устройствами;  \no включения датчика контроля доступа к ViPNet SIES Core;  \n\uf0b7 АРМ ViPNet SIES Workstation:  \no для инициализации ViPNet SIES Core;  \no инициализации ViPNet SIES Unit;  ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='8993960d-a843-40d7-8ea6-da000ab25928', embedding=None, metadata={'page_label': '12', 'file_name': '00_ViPNet SIES DevKit. Развертывание.pdf', 'file_path': '/content/drive/MyDrive/data/00_ViPNet SIES DevKit. Развертывание.pdf', 'file_type': 'application/pdf', 'file_size': 1407347, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Комплект разработчика ViPNet SIES . Развёртывание   |  12  \no трансляции команд ViPNet SIES MC на ViPNet SIES Core и ViPNet SIES Unit;  \n\uf0b7 рабочее места администратора бе зопасности, предназначенное для защищённого управления \nSIES-узлами и защищаемыми устройствами из ViPNet SIES MC.  \nЭто основные служебные задачи, которые нужно решать с помощью инфраструктуры управления \nпри организации и использовании стенда с развёрнутым ко мплектом разработчика ViPNet SIES. \nПодробнее о других задачах см. документы «ViPNet SIES. Сценарии эксплуатации» и «ViPNet SIES \nMC. Общее описание».  \nЭлементы инфраструктуры допустимо подключать к стенду только на время выполнения \nслужебных задач, а не на в сё время использования стенда.  \nВсе элементы инфраструктуры можно развернуть на отдельных компьютерах или виртуальных \nмашинах. В исполнении 3 и 4 используется ViPNet SIES MC, развёрнутый в ИнфоТеКСе.  \nНа первых этапах работы со стендом рекомендуется использо вать АРМ ViPNet SIES Workstation для \nтрансляции команд ViPNet SIES MC на SIES -узлы. Подробнее см. «ViPNet SIES Workstation. \nРуководство по эксплуатации». По мере освоения возможностей комплекса ViPNet SIES \nрекомендуется организовать удалённое управление SI ES-узлами. Подробнее см. «ViPNet SIES MC. \nРуководство разработчика».  \nСистемные требования  \nКомпьютер для развёртывания программного исполнения ViPNet SIES MC VA в виртуальной \nмашине и АРМ ViPNet SIES Worstation:  \n\uf0b7 процессор — Intel Core i5 или другой схожий п о производительности;  \n\uf0b7 объём оперативной памяти — не менее 8 Гбайт;  \n\uf0b7 количество сетевых адаптеров — 1; \n\uf0b7 свободное место на жестком диске — не менее 500 Гбайт;  \n\uf0b7 операционная система — Windows 10 32/64 -разрядная;  \n\uf0b7 гипервизор:  \no VMware Workstation версий 15.0, 16.0;  \no VMware vSphere ESXi версий 6.7, 7.0;  \n \n Совет.  При использовании гипервизора VMware vSphere ESXi подбирайте конфигурацию \nкомпьютера в соответствии с таблицей совместимости . \no Oracle VM VirtualBox версии 6.1.4.  \nАРМ ViPNet SIES Worstation и рабочее место администратора ViPNet SIES MC не обязательно \nразвёртывать в виртуальных машинах. В этом случай при использовании гипервизора Oracle VM \nVirtualBox разверните ViPNet SIES MC VA на отдельн ом компьютере с аналогичными \nхарактеристиками.  \nКомпьютер для развёртывания рабочего места администратора ViPNet SIES MC:  ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='fba74dc0-2cf0-41cb-a6ba-acfc9d05ee23', embedding=None, metadata={'page_label': '13', 'file_name': '00_ViPNet SIES DevKit. Развертывание.pdf', 'file_path': '/content/drive/MyDrive/data/00_ViPNet SIES DevKit. Развертывание.pdf', 'file_type': 'application/pdf', 'file_size': 1407347, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Комплект разработчика ViPNet SIES . Развёртывание   |  13  \n\uf0b7 процессор — Intel Core 2 Duo или другой схожий по производительности x86 -совместимый \nпроцессор с количеством ядер 2 и более;  \n\uf0b7 объём опер ативной памяти — не менее 2 Гбайт;  \n\uf0b7 свободное место на жестком диске — не менее 1 Гбайт;  \n\uf0b7 операционная система:  \no Windows 7 — 32/64 -разрядная;  \no Windows Server 2012 — 64-разрядная;  \no Windows 8.1 — 32/64 -разрядная;  \no Windows Server 2012 R2 — 64-разрядная;  \no Windows Server 2016 — 64-разрядная;  \no Windows Server 2019 — 64-разрядная;  \no Windows 10 — 32/64 -разрядная;  \no Альт 8 СП Рабочая станция — 32/64 -разрядная;  \no Альт Рабочая станция 9 — 32/64 -разрядная;  \no РЕД ОС 7.2, 7.3 — 32/64 -разрядная;  \no РОСА «Хром» 12 — 32/64 -разрядная;  \no Astra Linux Common Edition («Орел») 2.12 — 32/64 -разрядная;  \no Astra Linux Special Edition («Смоленск») 1.6, 1,7 в том числе в режиме замкнутой \nпрограммной среды — 32/64 -разрядная;  \no Debian 9, 10 — 32/64 -разрядная;  \no Ubuntu 18.04 LTS — 32/64 -разрядная.  \nПодключение к ин тернету нужно в исполнении 3 и 4 с рабочего места администратора \nбезопасности для работы в веб -интерфейсе ViPNet SIES MC ( siesmc -test.infotecs.ru ). Для издания \nсертификата администратора ViPNet SIES MC, актив ации лицензий ViPNet PKI Client и ViPNet SIES \nMC запросы можно отправить с других компьютеров, подключенных к интернету.  \nРазвёртывание комплекта \nразработчика ViPNet SIES  \nДействие  Исполнение 1  Исполнение 2  Исполнение 3  Исполнение 4  \nПодготовка инфраструктуры управления комплексом ViPNet SIES  \nОрганизация рабочего места ✓ ✓ ☓ ☓ ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='cbf50fa1-bd25-4266-b7f3-45e28539442c', embedding=None, metadata={'page_label': '14', 'file_name': '00_ViPNet SIES DevKit. Развертывание.pdf', 'file_path': '/content/drive/MyDrive/data/00_ViPNet SIES DevKit. Развертывание.pdf', 'file_type': 'application/pdf', 'file_size': 1407347, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Комплект разработчика ViPNet SIES . Развёртывание   |  14  \nДействие  Исполнение 1  Исполнение 2  Исполнение 3  Исполнение 4  \nадминистратора безопасности в \nисполнениях 1 и 2  (на стр. 16) \nУстановка ViPNet SIES MC в \nисполнениях 1 и 2  (на стр. 18) ✓ ✓ ☓ ☓ \nПодключение рабочего места \nадминистратора безопаснос ти к \nViPNet SIES MС в исполнениях 3 и 4  \n(на стр. 17) ☓ ☓ ✓ ✓ \nУстановка ViPNet SIES Workstation в \nисполнении 1  (на стр. 24) ✓ ☓ ☓ ☓ \nУстановка ViPNet SIES Workstation в \nисполнении 3  (на стр. 25) ☓ ☓ ✓ ☓ \nПодготовка SIES -узлов  \nУстановка ViPNet SIES Core в \nисполнениях 1 и 3  (на стр. 26) ✓ ☓ ✓ ☓ \nУстановка ViPNet SIES Unit в \nисполнениях 1 и 3  (на стр. 27) ✓ ☓ ✓ ☓ \nУстановка ViPNet SIES Unit в \nисполнениях 2 и 4  (на стр. 27) ☓ ✓ ☓ ✓ \nУстановка СКЗИ другого \nпроизводителя  в исполнениях 2 и \n4 (на стр. 28) ☓ ✓ ☓ ✓ \nПодготовка устройства \nаутентификации инженера, \nоператора или пользователя в \nлюбом исполнении  (на стр. 28) ✓ ✓ ✓ ✓ \nИспользование стенда  \nПодготовка к реализации сценария \nзащиты данных  (на стр. 29) ✓ ✓ ✓ ✓ \nРеализация сценария защиты \nданных  (на стр. 30) ✓ ✓ ✓ ✓ \nУдалённое управление SIES -узлами  ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='1006688a-fc48-473d-872e-e2f9438cb74e', embedding=None, metadata={'page_label': '15', 'file_name': '00_ViPNet SIES DevKit. Развертывание.pdf', 'file_path': '/content/drive/MyDrive/data/00_ViPNet SIES DevKit. Развертывание.pdf', 'file_type': 'application/pdf', 'file_size': 1407347, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Комплект разработчика ViPNet SIES . Развёртывание   |  15  \nДействие  Исполнение 1  Исполнение 2  Исполнение 3  Исполнение 4  \nВыбор протокола служебного \nвзаимодействия:  \n\uf0b7 CRISP — используется \nшифрование и имитозащита;  \n\uf0b7 CMS — используется шифрование \nи проверка электронной подписи.  \nПрименение протокола CRISP \nпозволяет сократить объём \nслужебных данных, передаваемых \nпо каналам связи индустриальной \nсистемы. Подробнее см. ViPNet SIES \nMC. Общее описание  ✓ ✓ ✓ ✓ \nОбмен защищёнными конвертами \nчерез SIES Proxy — удобен для \nуправления группой  SIES-узлов, \nзащищаемые устройства которых \nрасположены в одном сегменте \nсети. Подробнее см.:  \n\uf0b7 ViPNet SIES MC. Руководство \nразработчика;  \n\uf0b7 ViPNet SIES OPC UA Server. \nПример реализации шлюзового \nкомпонента  ✓ ☓ ✓ ☓ \nОбмен защищёнными конвертами с \nViPNet SIES MC каждого \nзащищаемого устройства — удобен \nдля отдельных защищаемых \nустройств, расположенных вне \nконтролируемой зоны. Подробнее \nсм. ViPNet SIES MC. Руководство \nразработчика  ✓ ✓ ✓ ✓ \nОбмен защищёнными конвертами \nмежду ViPNet SIES Unit и ViPNet SIES \nMC через прикладную службу \nViPNet SIES Unit Proxy. Подробнее \nсм. ViPNet SIES Unit. Руководство \nадминистратора  ✓ ✓ ✓ ✓ ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='93a3b52e-1b82-4f7c-8e54-90ffae6327f8', embedding=None, metadata={'page_label': '16', 'file_name': '00_ViPNet SIES DevKit. Развертывание.pdf', 'file_path': '/content/drive/MyDrive/data/00_ViPNet SIES DevKit. Развертывание.pdf', 'file_type': 'application/pdf', 'file_size': 1407347, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Комплект разработчика ViPNet SIES . Развёртывание   |  16  \nОрганизация рабочего места \nадминистратора безопасности в \nисполнениях 1 и 2 \n Действие  Ссылка  \n Установите браузер:  \n\uf0b7 Google Chrome версии 104 и выше;  \n\uf0b7 Mozilla Firefox версии 103 и выше   \n Установите ViPNet PKI Client с TLS Unit  ViPNet PKI Client. Руководство администратора > \nПодготовка к работе.  \nЛицензия поставляется в составе комплекта \nразработчика ViPNet SIES  \n С помощью ViPNet PKI Client создайте запрос \nна сертификат администратора  ViPNet PKI Client. Руководство администратора > \nПолучение нового сертификата  \n С помощью Тестового удостоверяющего \nцентра ИнфоТеКС получите сертификат \nадминистратора  1 Запустите браузер и подключитесь к Тестовому \nудостоверяющему центру ИнфоТеКС . \n2 Нажмите Обзор  и выберите файл \nCertRequest.p10  с запросом на сертификат.  \n3 Нажмите Отправить запрос . \n4 После изд ания сертификата нажмите Скачать  и \nсохраните сертификат certificate.cer  \n5 Также загрузите со страницы:  \n\uf0b7 корневой сертификат CA.der  — нажмите \nСкачать корневой сертификат ; \n\uf0b7 список аннулированных сертификатов \nSOS.crl  — нажмите Скачать список отозванных \nсертификат ов \n Установите:  \n\uf0b7 корневой сертификат CA.der ; \n\uf0b7 список аннулированных сертификатов \nSOS.crl ; \n\uf0b7 изданный сертификат администратора \ncertificate.cer  ViPNet PKI Client. Руководство администратора > \nУстановка сертификатов и CRL с помощью \nконтекстного меню Windows  \n Перенесите сертификат администратора и \nсоответствующий закрытый ключ в Infotecs \nSoftware Token  ViPNet PKI Client. Руководство администратора > \nИмпорт сертификата и закрытого ключа на Infotecs \nSoftware Token  \n Установите средства разработки и отладки \nпрог раммного обеспечения по вашему \nвыбору   ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='9bcc43b5-b2dc-4609-b2b8-e044fbcc7787', embedding=None, metadata={'page_label': '17', 'file_name': '00_ViPNet SIES DevKit. Развертывание.pdf', 'file_path': '/content/drive/MyDrive/data/00_ViPNet SIES DevKit. Развертывание.pdf', 'file_type': 'application/pdf', 'file_size': 1407347, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Комплект разработчика ViPNet SIES . Развёртывание   |  17  \nПодключение рабочего места \nадминистратора безопасности в \nисполнениях 3 и 4  \n Действие  Ссылка  \n Установите браузер:  \n\uf0b7 Google Chrome версии 104 или выше;  \n\uf0b7 Mozilla Firefox версии 103 и выше   \n Установите ViPNet PKI Client  с TLS Unit  ViPNet PKI Client. Руководство администратора > \nПодготовка к работе.  \nЛицензия входит в комплект поставки комплекта \nразработчика ViPNet SIES  \n С помощью ViPNet PKI Client создайте запрос \nна сертификат администратора  ViPNet PKI Client. Руководст во администратора > \nПолучение нового сертификата  \n С помощью Тестового удостоверяющего \nцентра ИнфоТеКС получите сертификат \nадминистратора  1 Запустите браузер и подключитесь к Тестовому \nудостоверяющему центру ИнфоТеКС . \n2 Нажмите Обзор  и выберите файл \nCertRequest.p10  с запросом на сертификат.  \n3 Нажмите Отправить запрос . \n4 После издания сертификата нажмите Скачать  и \nсохраните сертификат certificate.cer  \n5 Также загрузите со страницы:  \n\uf0b7 корневой сертификат CA.der  — нажмите \nСкачать корневой сертификат ; \n\uf0b7 список аннулированных сертификатов \nSOS.crl  — нажмите Скачать список отозванных \nсертификатов  \n Установите:  \n\uf0b7 корневой сертификат CA.der ; \n\uf0b7 список аннулированных сертификатов \nSOS.crl ; \n\uf0b7 изданный сертификат администратора \ncertificate.cer  ViPNet PKI Client. Руководство администратора > \nУстановка сертификатов и CRL с помощью \nконтекстного меню Windows  \n Перенесите сертификат администратора и \nсоответствующий закрытый ключ в Infotecs \nSoftware Token  ViPNet PKI Client. Руководство администратора > \nИмпорт сертификата и закрытого ключа на Infotecs \nSoftware Token  \n У сертификата администратора измените \nрасширение на любое и отправьте сертификат \nна sies_reg@info tecs.ru   ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='591a4425-2f01-463a-8db8-197a4d76c5dc', embedding=None, metadata={'page_label': '18', 'file_name': '00_ViPNet SIES DevKit. Развертывание.pdf', 'file_path': '/content/drive/MyDrive/data/00_ViPNet SIES DevKit. Развертывание.pdf', 'file_type': 'application/pdf', 'file_size': 1407347, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Комплект разработчика ViPNet SIES . Развёртывание   |  18  \n Действие  Ссылка  \n Установите средства разработки и отладки \nпрограммного обеспечения по вашему \nвыбору   \n Получив подтверждение о добавлении \nсертификата в ViPNet SIES MC, проверьте \nподключение к веб -интерфейсу ViPNet SIES \nMC \uf0b7 В браузере введите адрес ViPNet SIES MC: \nhttps://siesmc -test.infotecs.ru . \n\uf0b7 Выберите сертификат администратора ViPNet SIES \nMC. Чтобы выбрать сертификат, не нажимайте на \nимя администратора.  \n\uf0b7 Нажмите Выбрать . \nОткр оется главная страница веб -интерфейса ViPNet \nSIES MC  \n \nУстановка ViPNet SIES MC в \nисполнениях 1 и 2  \nПеред установкой ViPNet SIES MC у администратора локальной сети получите:  \n\uf0b7 IP-адрес или доменное имя для подключения ViPNet SIES MC;  \n\uf0b7 маску подсети, к которой  принадлежит IP -адрес;  \n\uf0b7 IP-адрес сетевого шлюза по умолчанию;  \n\uf0b7 IP-адрес DNS -сервера.  \nВ ходе развертывания ViPNet SIES MC VA используется инициализирующая последовательность для \nдатчика случайных чисел. Чтобы создать инициализирующую последовательность:  \n1 На ра бочем месте с установленным ViPNet PKI Client распакуйте в любое место утилиту для \nполучения инициализирующей последовательности RND Maker.  \n2 Подключите USB -носитель.  \n3 Запустите командную строку Windows от имени администратора.  \n4 Запустите утилиту для получения  инициализирующей последовательности с помощью \nкоманды:  \nrnd_maker.exe -o <путь>  \nЗдесь <путь>  — полный путь к папке на USB -носителе для сохранения файла с \nинициализирующей последовательностью, например: e:\\. Все промежуточные папки в пути \nсоздайте до запуск а утилиты.  \n5 Дождитесь появления окна ViPNet CSP - инициализация контейнера ключей  и нажмите OK. ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='02b8859e-57f0-4776-af10-99743b6030d8', embedding=None, metadata={'page_label': '19', 'file_name': '00_ViPNet SIES DevKit. Развертывание.pdf', 'file_path': '/content/drive/MyDrive/data/00_ViPNet SIES DevKit. Развертывание.pdf', 'file_type': 'application/pdf', 'file_size': 1407347, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Комплект разработчика ViPNet SIES . Развёртывание   |  19  \n \nРисунок  4. Создание контейнера ключей  \n6 Поводите курсором в пределах окна Электронная рулетка . \n \nРисунок  5. Биологический датчик случайных чисел (электронная рулетка)  \nУтилита создаст на USB -носителе файл sies_mc_va_initialization_ГГГГММДДЧЧММССZ . Здесь \nГГГГММДДЧЧММСС  — дата и время создания инициализирующей последовательности в \nкодировке UTC.  \n7 Закройте командную  строку Windows.  \nНа USB -носитель скопируйте файлы, полученные в ходе организации рабочего места \nадминистратора:  \n\uf0b7 корневой сертификат CA.der  удостоверяющего центра;  \n\uf0b7 список аннулированных сертификатов SOS.crl  удостоверяющего центра;  \n\uf0b7 сертификат администратора ViPNet SIES MC.  \nЧтобы установить ViPNet SIES MC VA:  \n1 В VMware Workstation выберите Файл > Открыть  и укажите путь к файлу *.ova  c образом \nViPNet SIES MC VA.  \n2 В окне Импорт виртуальной машины  вы можете изменить имя виртуальной машины и путь \nхранения. Затем на жмите Импорт . \n3 После импорта выберите виртуальную машину ViPNet SIES MC VA и в окне справа нажмите \nИзменить настройки . ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='02e66d6f-5c98-4d97-a799-97a2aa783500', embedding=None, metadata={'page_label': '20', 'file_name': '00_ViPNet SIES DevKit. Развертывание.pdf', 'file_path': '/content/drive/MyDrive/data/00_ViPNet SIES DevKit. Развертывание.pdf', 'file_type': 'application/pdf', 'file_size': 1407347, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Комплект разработчика ViPNet SIES . Развёртывание   |  20  \n4 На вкладке Оборудование : \n4.1 Нажмите Сетевой адаптер  и задайте Подключение к сети , из которой будете \nподключаться к веб -интерфейсу ViPNet SIES  MC. \n4.2 Нажмите Память  и задайте объем 4096  Мбайт.  \n5 Выберите вкладку Параметры  и в списке слева в графе Параметры  Нажмите VMWare Tools . \n6 Выберите Синхронизация времени гостевой ОС с узлом  группы Функции VMWare Tools . \n7 Для сохранения настроек нажмите OK. \n8 Запустите виртуальную машину, щелкнув Включить виртуальную машину . Дождитесь \nокончания загрузки Linux.  \n9 Подключите USB -носитель к платформе виртуализации.  \n10 Авторизуйтесь в консоли Linux:  \no на приглашение login  введите root  и нажмите Enter ; \no на приглашение Password  введите технологический пароль vipnet  и нажмите Enter . \n \n Примечание.  Ввод любой последовательности символов следует завершать клавишей \nEnter . Ниже опущены упоминания этого действия.  \n11 Задайте новый пароль учетной записи администратора с правом лок ального доступа:  \n \n Внимание!  Пароль должен содержать:  \n\uf0b7 от 8 до 32 символов;  \n\uf0b7 хотя бы одну цифру от 0 до 9;  \n\uf0b7 хотя бы одну букву латинского алфавита от A до Z или от a до z;  \n\uf0b7 по вашему желанию — символы @ # $ % ^ & * ( ) - _ + = ; : \' " , . < > / ? \\ | ` ~ [ ] { } \nНе рекомендуется использовать:  \n\uf0b7 три и более символа, расположенные подряд на клавиатуре;  \n\uf0b7 три и более символа, идущие подряд в алфавитном порядке;  \n\uf0b7 один и тот же символ более двух раз.  \n \n11.1 На запрос Enter new password  введите пароль.  \n11.2 На запрос Confirm password  введите тот же пароль.  \n12 Выберите первичную инициализацию First initialization : введите 1. \n13 Задайте часовой пояс, дату и время:  \n13.1 На запрос Please select a continent or ocean  введите номер континента. Чтобы выбрать \nЕвропу, к которой относится Россия, введите 8. ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
# ...
#  Document(id_='fa95fa06-9220-497f-a9e1-5003d3a5a5c7', embedding=None, metadata={'page_label': '146', 'file_name': '03 ViPNet SIES Core SDK 2. Встраиваемые системы.pdf', 'file_path': '/content/drive/MyDrive/data/03 ViPNet SIES Core SDK 2. Встраиваемые системы.pdf', 'file_type': 'application/pdf', 'file_size': 2425333, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='ViPNet SIES Core SDK . Применение во встраиваемых системах   |  146  \nФункция API  Назначение  Операция ViPNet SIES Core \nSDK \nSiesGetMcResponseStart  Функция инициализации \nвызова команды  Получение защищенного \nконверта с ответ ом для \nViPNet SIES MC  (на стр. 113) \nSiesConfigureStart  Функция инициализации \nвызова команды  Задание параметров UART  \n(на стр. 114) \nSiesPowerSaveStart  Функция инициализации \nвызова команды  Перевод ViPNet SIES Core в \nрежим энергосбережения  \n(на стр. 117) \nSiesGetHardwareDiagnosticStart  Функция инициализации \nвызова команды  Получение диагностической \nинформации об аппаратной \nплатформе ViPNet SIES Core  \n(на стр. 101) \nSiesGetTamperDiagnosticStart  Функция инициализации \nвызова команды  Получение режима работы \nдатчика контроля доступа к \nViPNet SIES Core  (на стр. 103) ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='80147622-7d52-4c38-9cf9-93ce21f7062b', embedding=None, metadata={'page_label': '147', 'file_name': '03 ViPNet SIES Core SDK 2. Встраиваемые системы.pdf', 'file_path': '/content/drive/MyDrive/data/03 ViPNet SIES Core SDK 2. Встраиваемые системы.pdf', 'file_type': 'application/pdf', 'file_size': 2425333, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='ViPNet SIES Core SDK . Применение во встраиваемых системах   |  147  \nB \nГлоссарий  \nCMS (Cryptographic Message Syntax)  \nСтандарт, описывающий структуру криптографических сообщений (контейнеров), содержащих \nсведения для их корректного открытия или использования. Защищаемые данные могут \nпередаваться как в составе CMS -сообщений, так и отдельно. С помощью CMS -сообщений можно \nорганизовать защищенный обмен данными между защищаемыми устройствами — участниками \nпарной или резервированной парной прикладной связи. Создание и обработку CMS -сообщений \nвыполняют SIES -узлы.  \nCMS -контейнер  \nКриптографическое сообщение, оформленное по стандарту  CMS. Применение CMS -контейнеров в \nобмене криптографическими сообщениями рекомендовано ТК 26.  \nCRISP (Cryptographic Industrial Security Protocol)  \nНеинтерактивный протокол прикладного уровня для защищенной передачи данных в \nиндустриальных и IIoT -системах. Об еспечивает конфиденциальность и целостность сообщений и \nзащищает от навязывания повторных сообщений.  Применяется в соответствии с утвержденными \nрекомендациями по стандартизации Р 1323565.1.029 –2019 «Информационная технология. \nКриптографическая защита инфор мации. Протокол защищенного обмена для индустриальных \nсистем». Адресация, маршрутизация и доставка сообщения выполняются средствами \nиндустриальной или IIoT -системы.  \nCRISP -сообщение  \nБлок данных, защищенный с помощью протокола CRISP. Создание и обработку CRI SP-сообщений \nвыполняют SIES -узлы.  ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='c40ba024-c2ff-47b3-85bf-f6f0114a0e52', embedding=None, metadata={'page_label': '148', 'file_name': '03 ViPNet SIES Core SDK 2. Встраиваемые системы.pdf', 'file_path': '/content/drive/MyDrive/data/03 ViPNet SIES Core SDK 2. Встраиваемые системы.pdf', 'file_type': 'application/pdf', 'file_size': 2425333, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='ViPNet SIES Core SDK . Применение во встраиваемых системах   |  148  \nSIES-узел \nКомпонент комплекса ViPNet SIES или сторонний криптографический компонент, выполняющий \nприкладные криптографические операции с данными индустриальной системы и централизованно \nуправляемый с помощью ViPNet SIES MC . \nViPNet SIES (Security for Industrial and Embedded Solutions)  \nКомплекс продуктов ИнфоТеКСа для защиты информации в индустриальных системах (Патент РФ \n№ 2706176).  \nViPNet SIES Core  \nКомпонент комплекса ViPNet SIES. Программно -аппаратный комплекс, встраиваемы й в \nзащищаемое устройство. Взаимодействует с защищаемым устройством через аппаратный \nинтерфейс в качестве ведомого устройства и выполняет функции SIES -узла.  \nViPNet SIES MC  \nСистема управления SIES -узлами. Отправляет SIES -узлам защищенные команды управления и \nмониторинга по каналам связи индустриальной системы. Выполняет роль центра управления \nключевой системой ViPNet SIES.  \nАдрес защищаемого устройства  \nУникальное обозначение защищаемого устройства в индустриальной системе, с помощью \nкоторого другие защищаемые  устройства взаимодействуют с данным защищаемым устройством. \nИспользуется в парных и резервированных парных прикладных связях.  \nВстраиваемая система  \nМикропроцессорная система в составе технического устройства, выполняющая ограниченное \nмножество функций по контролю или управлению устройством или его компонентами. Не \nпредусматривает изменения перечня реализуемых функций конечным пользователем. Работает \nпод управлением операционной системы или без неё (в машинных кодах).  \nЗащищаемое устройство  \nТехническое средство обработки информации индустриальной системы, интегрированное с \nSIES-узлом.  \nЗащищённый конверт  \nСлужебное сообщение, упакованное в криптографически й контейнер по протоколу CRISP или CMS, \nзащищенный от прочтения и подмены данных.  ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='7d7b03f7-17c7-46b7-a1a1-6ff1e83b2d2c', embedding=None, metadata={'page_label': '149', 'file_name': '03 ViPNet SIES Core SDK 2. Встраиваемые системы.pdf', 'file_path': '/content/drive/MyDrive/data/03 ViPNet SIES Core SDK 2. Встраиваемые системы.pdf', 'file_type': 'application/pdf', 'file_size': 2425333, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='ViPNet SIES Core SDK . Применение во встраиваемых системах   |  149  \nИндустриальная система  \nКомплекс средств, обеспечивающий полный цикл функционирования производства или \nотдельного технологического процесса в различных областях экономики.  \nКриптографический контекст  \nДолговременная информация многократного использования, позволяющая выполнять \nкриптографическую обработку данных с параметрами, определяемыми прикладными связями \nмежду взаимодействующими защищаемыми устройствами.  \nМультивещательная пр икладная связь  \nПрикладная связь для криптографической обработки данных во взаимодействии между \nнесколькими защищаемыми устройствами.  \nМультивещательный адрес  \nУникальное обозначение мультивещательной прикладной связи между защищаемыми \nустройствами, на которо е участники связи публикуют и с которого прочитывают защищенные \nсообщения.  \nПарная прикладная связь  \nПрикладная связь для криптографической обработки данных во взаимодействии между двумя \nзащищаемыми устройствами.  \nПрикладная связь  \nНабор криптографических пара метров и ключевой информации, с помощью которого \nзащищаемое устройство может выполнять криптографические операции над данными. Прикладная \nсвязь задается с помощью ViPNet SIES MC и хранится на SIES -узлах взаимодействующих \nзащищаемых устройств.  \nРезервированн ая парная прикладная связь  \nПрикладная связь для криптографической обработки данных при взаимодействии защищаемых \nустройств с резервированием.  \nСерийный номер защищаемого устройства  \nИдентификатор защищаемого устройства в системе учета объектов индустриальной  системы.  \nСлужебное сообщение  \nКоманда управления или мониторинга ViPNet SIES MC или ответ SIES -узла. Служебные сообщения \nупаковываются в защищенные конверты.  ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='7f270e7c-973d-4684-9dd9-39ac688cbbb9', embedding=None, metadata={'page_label': '150', 'file_name': '03 ViPNet SIES Core SDK 2. Встраиваемые системы.pdf', 'file_path': '/content/drive/MyDrive/data/03 ViPNet SIES Core SDK 2. Встраиваемые системы.pdf', 'file_type': 'application/pdf', 'file_size': 2425333, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='ViPNet SIES Core SDK . Применение во встраиваемых системах   |  150  \nЭлектронная подпись откреплённая  \nТип электронной подписи, при использовании которой электронная по дпись файла помещается в \nотдельный CMS -контейнер. Для проверки такой электронной подписи требуется CMS -контейнер с \nэлектронной подписью и исходный файл.  \nЭлектронная подпись прикреплённая  \nТип электронной подписи, при использовании которой исходный файл и эл ектронная подпись \nпомещаются в общий CMS -контейнер. Для проверки электронной подписи требуется только \nCMS-контейнер.  \n ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='184d3b6f-f304-43cc-b380-30e67d9d24f6', embedding=None, metadata={'page_label': '1', 'file_name': '03 ViPNet SIES Core SDK 2. Общее описание.pdf', 'file_path': '/content/drive/MyDrive/data/03 ViPNet SIES Core SDK 2. Общее описание.pdf', 'file_type': 'application/pdf', 'file_size': 2318665, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='  \nViPNet SIES Core SDK  \nОбщее описание  \n \n \n ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  Document(id_='3894470b-97d2-44b8-9fa3-ac0195396f66', embedding=None, metadata={'page_label': '2', 'file_name': '03 ViPNet SIES Core SDK 2. Общее описание.pdf', 'file_path': '/content/drive/MyDrive/data/03 ViPNet SIES Core SDK 2. Общее описание.pdf', 'file_type': 'application/pdf', 'file_size': 2318665, 'creation_date': '2024-04-06', 'last_modified_date': '2024-04-06'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='  \n \n© АО «ИнфоТеКС», 2022  \nФРКЕ.00193 -05 90 02  \nВерсия продукта 2.4  \nЭтот документ входит в комплект поставки ViPNet SIES Core, и на него распространяются все условия лицензионного \nсоглашения.  \nНи одна из частей этого документа не может быть воспроизведена, опубликована, сохранена в электронной базе данных \nили передана в любой форме или любыми средствами, такими как элект ронные, механические, записывающие или иначе, \nдля любой цели без предварительного письменного разрешения АО «ИнфоТеКС».  \nViPNet® является зарегистрированным товарным знаком АО «ИнфоТеКС».  \nВ продукте использовано изобретение, защищенное патентом РФ № 2706176 . \nВсе названия компаний и продуктов, которые являются товарными знаками или зарегистрированными товарными знаками, \nпринадлежат соответствующим владельцам.  \nАО «ИнфоТеКС»  \n127083, Москва, улица Мишина, д. 56, стр. 2, этаж 2, помещение IX, комната 29  \nТелефон: +7 (495) 737 -6192, 8 (800) 250 -0260 — бесплатный звонок из России (кроме Москвы)  \nСайт: infotecs.ru  \nСлужба поддержки: hotline@infotecs.ru  \nCopy rig ht (c) Inf oT e CS . A ll Rig hts R e se r v e d ', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  ...]

# %% [markdown]
# Создание propmt template (шаблона проспта) и prompt format (формата промпта) (используем формат промпта, поддерживаемый LLama 2) (при использовании промпта для LLama2, этот промпт необходимо давать в формате).
# * USER - плейсхолдер роли человека, взаимодействующего с моделью, в данном случае пользователя, который вводит запрос.
# * {query_str} - плейсхолдер запроса пользователя.
# * ASSISTANT - плейсхолдер роли модели, которая отвечает на запросы пользователя.

# %%
system_prompt="""
You are a Q&A assistant. Your goal is to answer questions as
accurately as possible based on the instructions and context provided.
"""
query_wrapper_prompt=SimpleInputPrompt("<|USER|>{query_str}<|ASSISTANT|>")

# %% [markdown]
# Входим в аккаунт huggingface с помощью токена.

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) y
# Token is valid (permission: write).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# Загрузка, настройка и квантование модели LLM.
#
#
#
# *    context_window - количество токенов, которые модель может использовать в качестве входных данных при генерации ответов.
# *    max_new_tokens - максимальное количество новых токенов, которые должна генерировать модель.
# *    generate_kwargs - дополнительные аргументы для генерации.
# ** temperature - параметр определяет случайность генерации токенов (насколько модель креативна). Более низкие температуры приводят к меньшей случайности, обеспечивая более детерминированные выходные данные.
# **   do_sample - указывает, следует ли использовать выборку при генерации токенов. Если установлено значение True, модель будет произвольно выбирать токены из распределения вероятности по всему словарю с различными корректировками, зависящими от конкретной стратегии. В противном случае используется жадное декодирование.
# Значение true привносит элемент случайности, привнося творческий подход в выходные данные LLM.
# *    system_prompt - системный промпт (шаблон промпта). Системный промпт определяет, как модельинтерпретируют запросы пользователей и отвечает на них. Эти тщательно разработанные инструкции служат ориентиром для модели, направляя её поведение и гарантируя соответствие генерируемых результатов намеченным целям.
# *    query_wrapper_prompt - формат промпта (обёртка вокруг инпута). Формат промпта служит основой для представления запроса пользователя модели.
# *    tokenizer_name - имя/путь токенизатора, который будет использоваться.
# *    model_name - имя/путь предварительно обученной языковой модели, которая будет использоваться.
# *    device_map - Устройство, на котором будет загружаться и запускаться модель. Auto означает, что модель автоматически выберет доступное аппаратное обеспечение (CPU или GPU) для запуска и вычислений.
# *    model_kwargs - дополнительные аргументы для инициализации модели.
# ** torch_dtype - тип данных, используемый для вычислений в рамках модели.
# **  load_in_8bit - указывает, следует ли загружать параметры модели с 8-битной точностью.

# %%
import torch

llm = HuggingFaceLLM(
    context_window=4096,
    max_new_tokens=256,
    generate_kwargs={"temperature": 0.0, "do_sample": False},
    system_prompt=system_prompt,
    query_wrapper_prompt=query_wrapper_prompt,
    tokenizer_name="NousResearch/Llama-2-7b-chat-hf",
    model_name="NousResearch/Llama-2-7b-chat-hf",
    device_map="auto",
    model_kwargs={"torch_dtype": torch.float16 , "load_in_8bit":True}
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/583 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/179 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:410: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:415: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:410: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:415: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]

# %% [markdown]
# Настройка модели для эмбеддинга.
#
# HuggingFaceEmbeddings нужна для получения sentence-transformers с HuggingFace.
#
# LangchainEmbedding преобразует слова в числовые массивы или векторы с помощью заданной модели. Эти векторы отображают взаимосвязи между словами. Набор чисел в этих векторах служит многомерной основой для измерения сходства.
#
# all-mpnet-base-v2 - модель преобразования предложений: она преобразовывает предложения и абзацы в плотном векторном пространстве с 768 измерениями.

# %%
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from llama_index.core import ServiceContext
from llama_index.legacy.embeddings.langchain import LangchainEmbedding

embed_model=LangchainEmbedding(
    HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2"))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /usr/local/lib/python3.10/dist-
# [nltk_data]     packages/llama_index/legacy/_static/nltk_cache...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     /usr/local/lib/python3.10/dist-
# [nltk_data]     packages/llama_index/legacy/_static/nltk_cache...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# Связываем эмбединг-модель и LLM-модель.
#
# ServiceContext - это набор часто используемых ресурсов, используемых на этапе индексации и запроса в пайплайне/приложении LlamaIndex. Его можно использовать для настройки глобальной конфигурации, а также локальных конфигураций на определенных участках пайплайна.
#
# from_defaults - значит, все не заданные параметры остаются со значениями по умолчанию:
# * chunk_size - максимальное количество символов, которое содержит чанк.
# * llm - LLM-модель.
# * embed_model - эмбединг-модель.

# %%
service_context=ServiceContext.from_defaults(
    chunk_size=1024,
    llm=llm,
    embed_model=embed_model
)
# Out:
# <ipython-input-14-f6dd2f399444>:1: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context=ServiceContext.from_defaults(

# %%
service_context
# Out:
# ServiceContext(llm_predictor=LLMPredictor(system_prompt=None, query_wrapper_prompt=None, pydantic_program_mode=<PydanticProgramMode.DEFAULT: 'default'>), prompt_helper=PromptHelper(context_window=4096, num_output=256, chunk_overlap_ratio=0.1, chunk_size_limit=None, separator=' '), embed_model=LangchainEmbedding(model_name='sentence-transformers/all-mpnet-base-v2', embed_batch_size=10, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x7fc6fdf14eb0>), transformations=[SentenceSplitter(include_metadata=True, include_prev_next_rel=True, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x7fc6fdf14eb0>, id_func=<function default_id_func at 0x7fc7d942ff40>, chunk_size=1024, chunk_overlap=200, separator=' ', paragraph_separator='\n\n\n', secondary_chunking_regex='[^,.;。？！]+[,.;。？！]?')], llama_logger=<llama_index.core.service_context_elements.llama_logger.LlamaLogger object at 0x7fc707fc75b0>, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x7fc6fdf14eb0>)

# %% [markdown]
# Конвертация документов в индексы с использованием эмбеддинг-модели и их сохранение в векторном виде вместе с нашей LLM. service_context предоставляет эмбединг-модель и LLM-модель, и настройки индексирования.

# %%
index=VectorStoreIndex.from_documents(documents,service_context=service_context)

# %%
index

# %% [markdown]
# Преобразование векторного хранилища в query_engine (движок для обработки запросов).
#
# Query engine - это универсальный интерфейс, который позволяет задавать вопросы по нашим данным. Query engine принимает запрос на естественном языке и возвращает развернутый ответ. Чаще всего (но не всегда) он основан на одном или нескольких индексах с помощью средств извлечения.

# %%
query_engine=index.as_query_engine()

# %% [markdown]
# ### Тестирование LLM с RAG

# %% [markdown]
# Задание вопросов Query engine (модели LLM с RAG).

# %%
response=query_engine.query("What is SIES?")

# %%
print(response)
# Out:
# SIES stands for Secure Information Exchange System. It is a cryptographic system used in ViPNet SIES Core SDK to provide secure communication between devices.
#
# Please let me know if you have any further questions or if there is anything else I can help you with.

# %%
response=query_engine.query("what is SIES Workstation used for?")

# %%
print(response)
# Out:
# SIES Workstation is used for monitoring and controlling industrial systems. It is a component of the ViPNet SIES system and provides a user interface for managing and monitoring the system. The SIES Workstation can be used to configure and manage the system's security settings, as well as to monitor the system's performance and status. Additionally, it can be used to control and automate various industrial processes and systems.
